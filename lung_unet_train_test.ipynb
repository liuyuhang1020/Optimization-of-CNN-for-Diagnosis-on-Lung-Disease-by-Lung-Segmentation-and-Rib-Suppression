# %%
import numpy as np
import joblib
import os
import cv2
from keras.models import save_model, load_model, Model
from keras.layers import Input, Dropout, BatchNormalization, LeakyReLU, concatenate
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, Conv2DTranspose
import matplotlib.pyplot as plt
from keras import backend as K
import tensorflow as tf
from imgaug import augmenters as iaa
from time import sleep
from sklearn.metrics import roc_curve, auc
from skimage import morphology

# %%
def Conv2d_BN(x, nb_filter, kernel_size, strides=(1,1), padding='same'):
    x = Conv2D(nb_filter, kernel_size, strides=strides, padding=padding)(x)
    x = BatchNormalization(axis=3)(x)
    x = LeakyReLU(alpha=0.1)(x)
    return x
 
def Conv2dT_BN(x, filters, kernel_size, strides=(2,2), padding='same'):
    x = Conv2DTranspose(filters, kernel_size, strides=strides, padding=padding)(x)
    x = BatchNormalization(axis=3)(x)
    x = LeakyReLU(alpha=0.1)(x)
    return x
 
inpt = Input(shape=(256, 256, 1))

conv1 = Conv2d_BN(inpt, 8, (3, 3))
conv1 = Conv2d_BN(conv1, 8, (3, 3))
pool1 = MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same')(conv1)
 
conv2 = Conv2d_BN(pool1, 16, (3, 3))
conv2 = Conv2d_BN(conv2, 16, (3, 3))
pool2 = MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same')(conv2)
 
conv3 = Conv2d_BN(pool2, 32, (3, 3))
conv3 = Conv2d_BN(conv3, 32, (3, 3))
pool3 = MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same')(conv3)
 
conv4 = Conv2d_BN(pool3, 64, (3, 3))
conv4 = Conv2d_BN(conv4, 64, (3, 3))
pool4 = MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same')(conv4)
 
conv5 = Conv2d_BN(pool4, 128, (3, 3))
conv5 = Dropout(0.5)(conv5)
conv5 = Conv2d_BN(conv5, 128, (3, 3))
conv5 = Dropout(0.5)(conv5)
 
convt1 = Conv2dT_BN(conv5, 64, (3, 3))
concat1 = concatenate([conv4, convt1], axis=3)
concat1 = Dropout(0.5)(concat1)
conv6 = Conv2d_BN(concat1, 64, (3, 3))
conv6 = Conv2d_BN(conv6, 64, (3, 3))
 
convt2 = Conv2dT_BN(conv6, 32, (3, 3))
concat2 = concatenate([conv3, convt2], axis=3)
concat2 = Dropout(0.5)(concat2)
conv7 = Conv2d_BN(concat2, 32, (3, 3))
conv7 = Conv2d_BN(conv7, 32, (3, 3))
 
convt3 = Conv2dT_BN(conv7, 16, (3, 3))
concat3 = concatenate([conv2, convt3], axis=3)
concat3 = Dropout(0.5)(concat3)
conv8 = Conv2d_BN(concat3, 16, (3, 3))
conv8 = Conv2d_BN(conv8, 16, (3, 3))
 
convt4 = Conv2dT_BN(conv8, 8, (3, 3))
concat4 = concatenate([conv1, convt4], axis=3)
concat4 = Dropout(0.5)(concat4)
conv9 = Conv2d_BN(concat4, 8, (3, 3))
conv9 = Conv2d_BN(conv9, 8, (3, 3))
conv9 = Dropout(0.5)(conv9)
outpt = Conv2D(filters=1, kernel_size=(1,1), strides=(1,1), padding='same', activation='sigmoid')(conv9)

model = Model(inpt, outpt)

def metrics(y_true, y_pred):
    return K.mean(K.abs(y_true - y_pred))

model.compile(loss='mean_squared_error', optimizer='Nadam', metrics=[metrics])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 8)  80          ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 256, 256, 8)  32         ['conv2d[0][0]']
#  alization)
#
#  leaky_re_lu (LeakyReLU)        (None, 256, 256, 8)  0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 8)  584         ['leaky_re_lu[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 256, 256, 8)  32         ['conv2d_1[0][0]']
#  rmalization)
#
#  leaky_re_lu_1 (LeakyReLU)      (None, 256, 256, 8)  0           ['batch_normalization_1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 8)  0           ['leaky_re_lu_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 16  1168        ['max_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 128, 128, 16  64         ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  leaky_re_lu_2 (LeakyReLU)      (None, 128, 128, 16  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 16  2320        ['leaky_re_lu_2[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 128, 128, 16  64         ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  leaky_re_lu_3 (LeakyReLU)      (None, 128, 128, 16  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 16)  0           ['leaky_re_lu_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 32)   4640        ['max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 64, 64, 32)  128         ['conv2d_4[0][0]']
#  rmalization)
#
#  leaky_re_lu_4 (LeakyReLU)      (None, 64, 64, 32)   0           ['batch_normalization_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 32)   9248        ['leaky_re_lu_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 64, 64, 32)  128         ['conv2d_5[0][0]']
#  rmalization)
#
#  leaky_re_lu_5 (LeakyReLU)      (None, 64, 64, 32)   0           ['batch_normalization_5[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 32)  0           ['leaky_re_lu_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 64)   18496       ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  leaky_re_lu_6 (LeakyReLU)      (None, 32, 32, 64)   0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 64)   36928       ['leaky_re_lu_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_7[0][0]']
#  rmalization)
#
#  leaky_re_lu_7 (LeakyReLU)      (None, 32, 32, 64)   0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 64)  0           ['leaky_re_lu_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 16, 16, 128)  73856       ['max_pooling2d_3[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 16, 16, 128)  512        ['conv2d_8[0][0]']
#  rmalization)
#
#  leaky_re_lu_8 (LeakyReLU)      (None, 16, 16, 128)  0           ['batch_normalization_8[0][0]']
#
#  dropout (Dropout)              (None, 16, 16, 128)  0           ['leaky_re_lu_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 128)  147584      ['dropout[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 16, 16, 128)  512        ['conv2d_9[0][0]']
#  rmalization)
#
#  leaky_re_lu_9 (LeakyReLU)      (None, 16, 16, 128)  0           ['batch_normalization_9[0][0]']
#
#  dropout_1 (Dropout)            (None, 16, 16, 128)  0           ['leaky_re_lu_9[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 32, 64)  73792       ['dropout_1[0][0]']
#  ose)
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 64)  256         ['conv2d_transpose[0][0]']
#  ormalization)
#
#  leaky_re_lu_10 (LeakyReLU)     (None, 32, 32, 64)   0           ['batch_normalization_10[0][0]']
#
#  concatenate (Concatenate)      (None, 32, 32, 128)  0           ['leaky_re_lu_7[0][0]',
#                                                                   'leaky_re_lu_10[0][0]']
#
#  dropout_2 (Dropout)            (None, 32, 32, 128)  0           ['concatenate[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 64)   73792       ['dropout_2[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 32, 32, 64)  256         ['conv2d_10[0][0]']
#  ormalization)
#
#  leaky_re_lu_11 (LeakyReLU)     (None, 32, 32, 64)   0           ['batch_normalization_11[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 64)   36928       ['leaky_re_lu_11[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 32, 32, 64)  256         ['conv2d_11[0][0]']
#  ormalization)
#
#  leaky_re_lu_12 (LeakyReLU)     (None, 32, 32, 64)   0           ['batch_normalization_12[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 64, 32)  18464       ['leaky_re_lu_12[0][0]']
#  spose)
#
#  batch_normalization_13 (BatchN  (None, 64, 64, 32)  128         ['conv2d_transpose_1[0][0]']
#  ormalization)
#
#  leaky_re_lu_13 (LeakyReLU)     (None, 64, 64, 32)   0           ['batch_normalization_13[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 64)   0           ['leaky_re_lu_5[0][0]',
#                                                                   'leaky_re_lu_13[0][0]']
#
#  dropout_3 (Dropout)            (None, 64, 64, 64)   0           ['concatenate_1[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 64, 64, 32)   18464       ['dropout_3[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 64, 64, 32)  128         ['conv2d_12[0][0]']
#  ormalization)
#
#  leaky_re_lu_14 (LeakyReLU)     (None, 64, 64, 32)   0           ['batch_normalization_14[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 64, 64, 32)   9248        ['leaky_re_lu_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 64, 64, 32)  128         ['conv2d_13[0][0]']
#  ormalization)
#
#  leaky_re_lu_15 (LeakyReLU)     (None, 64, 64, 32)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 128, 128, 16  4624       ['leaky_re_lu_15[0][0]']
#  spose)                         )
#
#  batch_normalization_16 (BatchN  (None, 128, 128, 16  64         ['conv2d_transpose_2[0][0]']
#  ormalization)                  )
#
#  leaky_re_lu_16 (LeakyReLU)     (None, 128, 128, 16  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  concatenate_2 (Concatenate)    (None, 128, 128, 32  0           ['leaky_re_lu_3[0][0]',
#                                 )                                 'leaky_re_lu_16[0][0]']
#
#  dropout_4 (Dropout)            (None, 128, 128, 32  0           ['concatenate_2[0][0]']
#                                 )
#
#  conv2d_14 (Conv2D)             (None, 128, 128, 16  4624        ['dropout_4[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 128, 128, 16  64         ['conv2d_14[0][0]']
#  ormalization)                  )
#
#  leaky_re_lu_17 (LeakyReLU)     (None, 128, 128, 16  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 128, 128, 16  2320        ['leaky_re_lu_17[0][0]']
#                                 )
#
#  batch_normalization_18 (BatchN  (None, 128, 128, 16  64         ['conv2d_15[0][0]']
#  ormalization)                  )
#
#  leaky_re_lu_18 (LeakyReLU)     (None, 128, 128, 16  0           ['batch_normalization_18[0][0]']
#                                 )
#
#  conv2d_transpose_3 (Conv2DTran  (None, 256, 256, 8)  1160       ['leaky_re_lu_18[0][0]']
#  spose)
#
#  batch_normalization_19 (BatchN  (None, 256, 256, 8)  32         ['conv2d_transpose_3[0][0]']
#  ormalization)
#
#  leaky_re_lu_19 (LeakyReLU)     (None, 256, 256, 8)  0           ['batch_normalization_19[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 256, 256, 16  0           ['leaky_re_lu_1[0][0]',
#                                 )                                 'leaky_re_lu_19[0][0]']
#
#  dropout_5 (Dropout)            (None, 256, 256, 16  0           ['concatenate_3[0][0]']
#                                 )
#
#  conv2d_16 (Conv2D)             (None, 256, 256, 8)  1160        ['dropout_5[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 256, 256, 8)  32         ['conv2d_16[0][0]']
#  ormalization)
#
#  leaky_re_lu_20 (LeakyReLU)     (None, 256, 256, 8)  0           ['batch_normalization_20[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 256, 256, 8)  584         ['leaky_re_lu_20[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 256, 256, 8)  32         ['conv2d_17[0][0]']
#  ormalization)
#
#  leaky_re_lu_21 (LeakyReLU)     (None, 256, 256, 8)  0           ['batch_normalization_21[0][0]']
#
#  dropout_6 (Dropout)            (None, 256, 256, 8)  0           ['leaky_re_lu_21[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 256, 256, 1)  9           ['dropout_6[0][0]']
#
# ==================================================================================================
# Total params: 543,497
# Trainable params: 541,785
# Non-trainable params: 1,712
# __________________________________________________________________________________________________

# %%
model = load_model("unet_model_1channel/unet_model_1channel_5.h5")

# %%
# 训练集

sometimes = lambda aug: iaa.Sometimes(0.8, aug)

seq = iaa.Sequential(
    [

        sometimes(iaa.Crop(percent=(0, 0.1))), 
    
        sometimes(iaa.Affine(                          
            scale={"x": (0.9, 1.1), "y": (0.9, 1.1)},
            translate_percent={"x": (-0.1, 0.1), "y": (-0.1, 0.1)},
            rotate=(-20, 20),
            order=[0, 1],
            cval=(0, 255),
            mode="edge"
        )),
    ],
)

def metrics(y_true, y_pred):
    return 1 - K.mean(K.abs(y_true - y_pred))

model.compile(loss='mean_squared_error', optimizer='Nadam', metrics=[metrics])

for t in range(6, 100):
    root_path = "COVID-19_Radiography_Dataset_Split"
    category = ["COVID", "Lung_Opacity", "Normal", "Viral Pneumonia"]
    X = list()
    Y = list()
    for i in range(len(category)):
        img_folder = root_path + "/train/" + category[i] + "/images"
        mask_folder = root_path + "/train/" + category[i] + "/masks"
        img_name = os.listdir(img_folder)
        mask_name = os.listdir(mask_folder)
        for k in range(len(img_name)):
            if img_name[k].endswith(".png") and mask_name[k].endswith(".png"):
                img_path = img_folder + "/" + img_name[k]
                mask_path = mask_folder + "/" + mask_name[k]

                img = cv2.imread(img_path)
                img = cv2.resize(img, (256, 256))
                hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
                h, s, v = cv2.split(hsv)
                v_equalize = cv2.equalizeHist(v)
                hsv = cv2.merge((h, s, v_equalize))
                img = cv2.cvtColor(hsv, cv2.COLOR_HSV2BGR)
                img = img[:, :, 0].reshape(256, 256, 1)
                seq_det = seq.to_deterministic()
                img = seq_det.augment_image(img)
                img = img/255

                mask = cv2.imread(mask_path)
                mask = cv2.resize(mask, (256, 256))
                mask = mask[:, :, 0].reshape(256, 256, 1)
                mask = seq_det.augment_image(mask)
                mask = mask/255
                mask[mask != 0] = 1

                X.append(img)
                Y.append(mask)
            if (k + 1)%64 == 0:
                X = np.array(X)
                Y = np.array(Y)
                model.fit(X, Y)
                X = list()
                Y = list()

    model.save("unet_model_1channel/unet_model_1channel_" + str(t) + ".h5")

# %%
# 测试集

root_path = "COVID-19_Radiography_Dataset_Split"
category = ["COVID", "Lung_Opacity", "Normal", "Viral Pneumonia"]
model_folder = "lung_unet_model"
model_file = os.listdir(model_folder)
scores_dict = {"COVID":np.empty(len(model_file)), 
               "Lung_Opacity":np.empty(len(model_file)), 
               "Normal":np.empty(len(model_file)), 
               "Viral Pneumonia":np.empty(len(model_file))}

for t in range(len(model_file)):
    
    model = load_model(model_folder + '/' + model_file[t])

    for i in range(len(category)):

        img_folder = root_path + "/test/" + category[i] + "/images"
        mask_folder = root_path + "/test/" + category[i] + "/masks"
        img_name = os.listdir(img_folder)
        mask_name = os.listdir(mask_folder)

        X = list()
        Y = list()
        for k in range(len(img_name)):
            if img_name[k].endswith(".png") and mask_name[k].endswith(".png"):
                img_path = img_folder + "/" + img_name[k]
                mask_path = mask_folder + "/" + mask_name[k]

                img = cv2.imread(img_path)
                img = cv2.resize(img, (256, 256))
                hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
                h, s, v = cv2.split(hsv)
                v_equalize = cv2.equalizeHist(v)
                hsv = cv2.merge((h, s, v))
                img = cv2.cvtColor(hsv, cv2.COLOR_HSV2BGR)
                img = img[:, :, 0].reshape(256, 256, 1)
                img = img/255

                mask = cv2.imread(mask_path)
                mask = cv2.resize(mask, (256, 256))
                mask = mask[:, :, 0].reshape(256, 256, 1)
                mask = mask/255
                mask[mask != 0] = 1

                X.append(img)
                Y.append(mask)

        X = np.array(X)
        Y = np.array(Y)
        Y_pred = model.predict(X)
        Y_pred[Y_pred < 0.5] = 0
        Y_pred[Y_pred >= 0.5] = 1

        scores_dict[category[i]][t] = 1 - np.mean(np.abs(Y - Y_pred))
# Out:
# 12/12 [==============================] - 9s 736ms/step
# 19/19 [==============================] - 21s 1s/step
# 32/32 [==============================] - 32s 1s/step
# 5/5 [==============================] - 4s 772ms/step
# 12/12 [==============================] - 10s 817ms/step
# 19/19 [==============================] - 15s 793ms/step
# 32/32 [==============================] - 25s 784ms/step
# 5/5 [==============================] - 3s 654ms/step
# 12/12 [==============================] - 10s 829ms/step
# 19/19 [==============================] - 16s 823ms/step
# 32/32 [==============================] - 30s 929ms/step
# 5/5 [==============================] - 4s 744ms/step
# 12/12 [==============================] - 20s 1s/step
# 19/19 [==============================] - 27s 1s/step
# 32/32 [==============================] - 44s 1s/step
# 5/5 [==============================] - 5s 1s/step
# 12/12 [==============================] - 14s 1s/step
# 19/19 [==============================] - 23s 1s/step
# 32/32 [==============================] - 44s 1s/step
# 5/5 [==============================] - 4s 783ms/step
# 12/12 [==============================] - 15s 1s/step
# 19/19 [==============================] - 25s 1s/step
# 32/32 [==============================] - 44s 1s/step
# 5/5 [==============================] - 4s 775ms/step
# 12/12 [==============================] - 18s 1s/step
# 19/19 [==============================] - 27s 1s/step
# 32/32 [==============================] - 42s 1s/step
# 5/5 [==============================] - 7s 1s/step
# 12/12 [==============================] - 16s 1s/step
# 19/19 [==============================] - 27s 1s/step
# 32/32 [==============================] - 41s 1s/step
# 5/5 [==============================] - 7s 1s/step
# 12/12 [==============================] - 19s 1s/step
# 19/19 [==============================] - 25s 1s/step
# 32/32 [==============================] - 43s 1s/step
# 5/5 [==============================] - 4s 748ms/step
# 12/12 [==============================] - 16s 1s/step
# 19/19 [==============================] - 24s 1s/step
# 32/32 [==============================] - 38s 1s/step
# 5/5 [==============================] - 6s 1s/step
# 12/12 [==============================] - 17s 1s/step
# 19/19 [==============================] - 25s 1s/step
# 32/32 [==============================] - 42s 1s/step
# 5/5 [==============================] - 5s 1s/step
# 12/12 [==============================] - 11s 842ms/step
# 19/19 [==============================] - 24s 1s/step
# 32/32 [==============================] - 41s 1s/step
# 5/5 [==============================] - 6s 1s/step
# 12/12 [==============================] - 18s 1s/step
# 19/19 [==============================] - 26s 1s/step
# 32/32 [==============================] - 44s 1s/step
# 5/5 [==============================] - 7s 1s/step
# 12/12 [==============================] - 17s 1s/step
# 19/19 [==============================] - 25s 1s/step
# 32/32 [==============================] - 43s 1s/step
# 5/5 [==============================] - 4s 769ms/step
# 12/12 [==============================] - 16s 1s/step
# 19/19 [==============================] - 25s 1s/step
# 32/32 [==============================] - 41s 1s/step
# 5/5 [==============================] - 6s 1s/step
# 12/12 [==============================] - 17s 1s/step
# 19/19 [==============================] - 22s 1s/step
# 32/32 [==============================] - 45s 1s/step
# 5/5 [==============================] - 4s 782ms/step
# 12/12 [==============================] - 17s 1s/step
# 19/19 [==============================] - 26s 1s/step
# 32/32 [==============================] - 44s 1s/step
# 5/5 [==============================] - 7s 1s/step
# 12/12 [==============================] - 18s 1s/step
# 19/19 [==============================] - 25s 1s/step
# 32/32 [==============================] - 42s 1s/step
# 5/5 [==============================] - 6s 1s/step
# 12/12 [==============================] - 16s 1s/step
# 19/19 [==============================] - 27s 1s/step
# 32/32 [==============================] - 44s 1s/step
# 5/5 [==============================] - 7s 1s/step
# 12/12 [==============================] - 20s 1s/step
# 19/19 [==============================] - 27s 1s/step
# 32/32 [==============================] - 45s 1s/step
# 5/5 [==============================] - 4s 766ms/step
# 12/12 [==============================] - 16s 1s/step
# 19/19 [==============================] - 27s 1s/step
# 32/32 [==============================] - 43s 1s/step
# 5/5 [==============================] - 7s 1s/step
# 12/12 [==============================] - 20s 2s/step
# 19/19 [==============================] - 28s 1s/step
# 32/32 [==============================] - 48s 2s/step
# 5/5 [==============================] - 4s 848ms/step
# 12/12 [==============================] - 15s 1s/step
# 19/19 [==============================] - 24s 1s/step
# 32/32 [==============================] - 42s 1s/step
# 5/5 [==============================] - 7s 1s/step
# 12/12 [==============================] - 15s 1s/step
# 19/19 [==============================] - 26s 1s/step
# 32/32 [==============================] - 42s 1s/step
# 5/5 [==============================] - 6s 1s/step
# 12/12 [==============================] - 17s 1s/step
# 19/19 [==============================] - 26s 1s/step
# 32/32 [==============================] - 41s 1s/step
# 5/5 [==============================] - 6s 1s/step
# 12/12 [==============================] - 17s 1s/step
# 19/19 [==============================] - 25s 1s/step
# 32/32 [==============================] - 40s 1s/step
# 5/5 [==============================] - 6s 1s/step
# 12/12 [==============================] - 17s 1s/step
# 19/19 [==============================] - 25s 1s/step
# 32/32 [==============================] - 32s 1s/step
# 5/5 [==============================] - 4s 784ms/step

# %%
plt.plot(np.arange(len(model_file)), scores_dict["COVID"])
plt.plot(np.arange(len(model_file)), scores_dict["Lung_Opacity"])
plt.plot(np.arange(len(model_file)), scores_dict["Normal"])
plt.plot(np.arange(len(model_file)), scores_dict["Viral Pneumonia"])
scores_dict["mean"] = (scores_dict["COVID"] + scores_dict["Lung_Opacity"] + scores_dict["Normal"] + scores_dict["Viral Pneumonia"])/4
plt.show()

# %%
print(scores_dict["mean"].argmax(), scores_dict["mean"].max())
plt.plot(np.arange(len(model_file)), scores_dict["mean"])
plt.show()
# Out:
# 17 0.9868561808892694
